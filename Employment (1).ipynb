# %%
import pandas as pd
employment_df = pd.read_csv('Employment.csv')
pd.options.display.float_format = '{:,.0f}'.format
employment_df
# Out:
#            Industry       Subsector  Year     Jan     Feb     Mar     Apr  \
# 0     Total nonfarm   Total nonfarm  2012 133,250 133,512 133,752  133834
# 1     Total nonfarm   Total nonfarm  2013 135,263 135,541 135,680  135871
# 2     Total nonfarm   Total nonfarm  2014 137,548 137,714 137,968  138293
# 3     Total nonfarm   Total nonfarm  2015 140,568 140,839 140,910  141194
# 4     Total nonfarm   Total nonfarm  2016 143,205 143,417 143,654  143851
# ..              ...             ...   ...     ...     ...     ...     ...
# 292  Other services  Other services  2018   5,812   5,818   5,821    5828
# 293  Other services  Other services  2019   5,856   5,860   5,883    5896
# 294  Other services  Other services  2020   5,940   5,951   5,860    4520
# 295  Other services  Other services  2021   5,328   5,339   5,356    5379
# 296  Other services  Other services  2022   5,610   5,647   5,660     NaN
#
#         May     Jun     Jul     Aug     Sep     Oct     Nov     Dec
# ...

# %%
employment_df_industry = employment_df.groupby('Industry')

# %%
industry_array=[]
for index, row in employment_df.iterrows():
    industry_array.append(employment_df.loc[index]["Industry"])
    
industry_array_final = []
for i in industry_array:
    if i not in industry_array_final:
        industry_array_final.append(i)
print(industry_array_final)
# Out:
# ['Total nonfarm', 'Total private', 'Goods-producing', 'Service-providing', 'Private service-providing', 'Government', 'Mining and logging', 'Construction', 'Manufacturing', 'Durable Goods', 'Nondurable Goods', 'Trade, transportation, and utilities', 'Wholesale trade', 'Retail trade', 'Transportation and warehousing', 'Utilities', 'Information', 'Financial activities', 'Professional and business services', 'Education and health services', 'Leisure and hospitality', 'Other services']

# %%
import matplotlib.pyplot as plt
dataframes_arr=[]
x_all = []
y_all = []
for i in industry_array_final:
    
    df_industry1=employment_df_industry.get_group(i)
    
    for index, row in df_industry1.iterrows():
        if df_industry1.loc[index]["Year"]==2022:
            df_industry1.at[index,"Average"]=(float(df_industry1.loc[index]["Jan"])+float(df_industry1.loc[index]["Feb"])+float(df_industry1.loc[index]["Mar"]))/3
        else:
            df_industry1.at[index,"Average"]=(float(df_industry1.loc[index]["Jan"])+float(df_industry1.loc[index]["Feb"])+float(df_industry1.loc[index]["Mar"])+float(df_industry1.loc[index]["Apr"])+float(df_industry1.loc[index]["May"])+float(df_industry1.loc[index]["Jun"])+float(df_industry1.loc[index]["Jul"])+float(df_industry1.loc[index]["Aug"])+float(df_industry1.loc[index]["Sep"])+float(df_industry1.loc[index]["Oct"])+float(df_industry1.loc[index]["Nov"])+float(df_industry1.loc[index]["Dec"]))/12

#     dataframes_arr.append(df_industry1)
#     print(df_industry1)
    x_array=[]
    y_array=[]
    for index, row in df_industry1.iterrows():
        x_array.append(df_industry1.loc[index]["Year"])
        y_array.append(df_industry1.loc[index]["Average"])

    x_all.append(x_array)
    y_all.append(y_array)
    plt.plot(x_array, y_array)
    plt.xticks(rotation = 90)
    plt.xlabel('Year')
    plt.ylabel('Employment')
    plt.title (df_industry1.loc[index]["Industry"])
#     plt.legend(loc="upper right")
#     plt.ylim([0, 200])
    plt.show()
# Out:
# /var/folders/qs/1lf83t810fd_mwlrhrsvknvc0000gn/T/ipykernel_72876/1358049745.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_industry1.at[index,"Average"]=(float(df_industry1.loc[index]["Jan"])+float(df_industry1.loc[index]["Feb"])+float(df_industry1.loc[index]["Mar"])+float(df_industry1.loc[index]["Apr"])+float(df_industry1.loc[index]["May"])+float(df_industry1.loc[index]["Jun"])+float(df_industry1.loc[index]["Jul"])+float(df_industry1.loc[index]["Aug"])+float(df_industry1.loc[index]["Sep"])+float(df_industry1.loc[index]["Oct"])+float(df_industry1.loc[index]["Nov"])+float(df_industry1.loc[index]["Dec"]))/12
# /var/folders/qs/1lf83t810fd_mwlrhrsvknvc0000gn/T/ipykernel_72876/1358049745.py:13: SettingWithCopyWarning:
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10))
for i in range(len(y_all)):
    plt.plot(x_all[i], y_all[i])
# plt.plot(combined['All'].loc[2010:2021],color='green', label='All')
plt.title('Employment Data')
plt.xlabel('Year')
plt.legend()
plt.ylabel('')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, '')

# %%
df_industry1=employment_df_industry.get_group("Total private")
for index, row in df_industry1.iterrows():
        if df_industry1.loc[index]["Year"]==2022:
            df_industry1.at[index,"Average"]=(float(df_industry1.loc[index]["Jan"])+float(df_industry1.loc[index]["Feb"])+float(df_industry1.loc[index]["Mar"]))/3
        else:
            df_industry1.at[index,"Average"]=(float(df_industry1.loc[index]["Jan"])+float(df_industry1.loc[index]["Feb"])+float(df_industry1.loc[index]["Mar"])+float(df_industry1.loc[index]["Apr"])+float(df_industry1.loc[index]["May"])+float(df_industry1.loc[index]["Jun"])+float(df_industry1.loc[index]["Jul"])+float(df_industry1.loc[index]["Aug"])+float(df_industry1.loc[index]["Sep"])+float(df_industry1.loc[index]["Oct"])+float(df_industry1.loc[index]["Nov"])+float(df_industry1.loc[index]["Dec"]))/12

df_industry1
# Out:
# /Users/tusharmalik/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/tusharmalik/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#          Industry      Subsector  Year     Jan     Feb     Mar     Apr  \
# ...

# %%
dataframes_arr
# Out:
# [         Industry      Subsector  Year     Jan     Feb     Mar     Apr  \
#  0   Total nonfarm  Total nonfarm  2012 133,250 133,512 133,752  133834
#  1   Total nonfarm  Total nonfarm  2013 135,263 135,541 135,680  135871
#  2   Total nonfarm  Total nonfarm  2014 137,548 137,714 137,968  138293
#  3   Total nonfarm  Total nonfarm  2015 140,568 140,839 140,910  141194
#  4   Total nonfarm  Total nonfarm  2016 143,205 143,417 143,654  143851
#  5   Total nonfarm  Total nonfarm  2017 145,628 145,818 145,960  146165
#  6   Total nonfarm  Total nonfarm  2018 147,662 148,064 148,289  148468
#  7   Total nonfarm  Total nonfarm  2019 150,100 150,124 150,348  150636
#  8   Total nonfarm  Total nonfarm  2020 152,128 152,504 151,006  130513
#  9   Total nonfarm  Total nonfarm  2021 143,017 143,727 144,431  144694
#  10  Total nonfarm  Total nonfarm  2022 149,744 150,494 150,925     NaN
#
#         May     Jun     Jul     Aug     Sep     Oct     Nov     Dec  Average
# ...
